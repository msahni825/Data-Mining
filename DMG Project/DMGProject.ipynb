# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
gapminder = pd.read_csv('F:/training.tsv' , delimiter = '\t' , encoding = 'utf-8')

# %%
print(gapminder.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4824 entries, 0 to 4823
# Data columns (total 28 columns):
# Unnamed: 0                        4824 non-null int64
# url                               4824 non-null object
# urlid                             4824 non-null int64
# boilerplate                       4824 non-null object
# alchemy_category                  4824 non-null object
# alchemy_category_score            4824 non-null float64
# avglinksize                       4824 non-null float64
# commonlinkratio_1                 4824 non-null float64
# commonlinkratio_2                 4824 non-null float64
# commonlinkratio_3                 4824 non-null float64
# commonlinkratio_4                 4824 non-null float64
# compression_ratio                 4824 non-null float64
# embed_ratio                       4824 non-null float64
# framebased                        4824 non-null int64
# frameTagRatio                     4824 non-null float64
# ...

# %%
list=gapminder['alchemy_category'].unique()

# %%
print(list)
# Out:
# ['business' 'recreation' 'health' 'sports' 'arts_entertainment'
#  'science_technology' 'gaming' 'culture_politics' 'computer_internet'
#  'law_crime' 'religion' 'weather' 'unknown']

# %%
print(len(list))
# Out:
# 13

# %%
g=gapminder.groupby('alchemy_category')
g

# %%
for alchemy_category,alchemy_category_gapminder in g:
    print(alchemy_category)
    print(alchemy_category_gapminder)
# Out:
# arts_entertainment
#       Unnamed: 0                                                url  urlid  \
# 5              6  http://gofashionlane.blogspot.tw/2012/06/ameri...   8685
# 12            17  http://www.guardian.co.uk/fashion/gallery/2012...   3946
# 25            37          http://www.collegehumor.com/video:1806201   1650
# 41            61  http://www.bannedinhollywood.com/banneds-after...  10530
# 42            62  http://mysuperchargedlife.com/blog/20-ways-to-...   8262
# 61            91  http://heidiklum.aol.com/category/fitness-and-...   4467
# 71           104  http://www.breakfastblogger.com/2007/06/21/bac...  10182
# 72           107  http://hailmaryjane.com/5-hysterical-stand-com...   2749
# 74           109  http://www.savoringthethyme.com/2011/02/panko-...   1659
# 77           112  http://community.livejournal.com/t_shirt_surge...   2331
# 85           124  http://hailmaryjane.com/12-hilarious-that-70s-...   2528
# ...

# %%
gapminder.max()
# Out:
# Unnamed: 0                                                                     7393
# url                               https://www.recyclebank.com/live-green/use-tea...
# urlid                                                                         10566
# boilerplate                       {"url":"zuzutop 2010 02 terracotta warriors an...
# alchemy_category                                                            weather
# alchemy_category_score                                                     0.999426
# avglinksize                                                                     363
# commonlinkratio_1                                                                 1
# commonlinkratio_2                                                                 1
# commonlinkratio_3                                                          0.980392
# commonlinkratio_4                                                          0.980392
# ...

# %%
gapminder.mean()
# Out:
# Unnamed: 0                           (3697.387023217247+0j)
# url                                    (7.25252756e-316+0j)
# urlid                                                    0j
# boilerplate                                              0j
# alchemy_category                                         0j
# alchemy_category_score              (0.6044113959991707+0j)
# avglinksize                         (2.9696805672133086+0j)
# commonlinkratio_1                  (0.46461170854456885+0j)
# commonlinkratio_2                  (0.21450341011629348+0j)
# commonlinkratio_3                  (0.09192802002446097+0j)
# commonlinkratio_4                  (0.04998595378772799+0j)
# compression_ratio                   (1.3265784768922078+0j)
# embed_ratio                        (-0.0579337094925373+0j)
# framebased                                               0j
# frameTagRatio                      (0.05671491075663353+0j)
# hasDomainLink                     (0.019071310116086235+0j)
# ...

# %%
gapminder.describe()
# Out:
#         Unnamed: 0         urlid  alchemy_category_score  avglinksize  \
# count  4824.000000   4824.000000             4824.000000  4824.000000
# mean   3697.387023   5318.204809                0.604411     2.969681
# std    2149.277496   3058.299346                0.212851    10.368000
# min       0.000000      5.000000                0.070833     0.000000
# 25%    1825.250000   2677.500000                0.453393     1.622443
# 50%    3712.500000   5309.500000                0.627201     2.104870
# 75%    5565.250000   7989.500000                0.781945     2.678199
# max    7393.000000  10566.000000                0.999426   363.000000
#
#        commonlinkratio_1  commonlinkratio_2  commonlinkratio_3  \
# count        4824.000000        4824.000000        4824.000000
# mean            0.464612           0.214503           0.091928
# std             0.198922           0.144211           0.093412
# min             0.000000           0.000000           0.000000
# ...

# %%
# %matplotlib inline
gapminder.plot()
